# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
#pip install matplotlib pcde kutuphaneyı eklerken bunu kullan

# %%
import numpy as np
xpoints=np.array([5,10,21])
ypoints=np.array([20,30,88])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([5,10,])
ypoints=np.array([20,30,])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
xpoints=np.array([5,10,125])
ypoints=np.array([20,30,45])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints)
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints,'o')
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints,marker='o')
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints,marker='*')
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints,'o--r') #0--den sonra yazdıgım rengı belirler
plt.show()

# %%
ypoints=np.array([25,32,55,12,33])
plt.plot(ypoints,'o-.b') #0--den sonra yazdıgım rengı belirler
plt.show()

# %%
ypoints=np.array([25,32,55,12,33,39,20,99,16])
plt.plot(ypoints,marker='o',ms=14)#ms okunaklıgı arttırıyor
plt.show()

# %%
ypoints=np.array([1,65,22,7])
plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
ypoints=np.array([1,65,22,7])
plt.plot(ypoints,linestyle='dashed')
plt.show()

# %%
ypoints=np.array([1,65,22,7])
plt.plot(ypoints,ls=":",linewidth=7.5) #cizgi genişliği
plt.show()

# %%
y2=np.array([5,10,125])
y1=np.array([20,30,456])
y3=np.array([20,302,9])
y4=np.array([120,31,1])

plt.plot(y1)
plt.plot(y2)
plt.plot(y3)
plt.plot(y4)

plt.show()

# %%
y2=np.array([5,25])
y1=np.array([4,45])
y3=np.array([3,60])
y4=np.array([2,64])
y5=np.array([2,45])
y6=np.array([2,25])


plt.plot(y1)
plt.plot(y2)
plt.plot(y3)
plt.plot(y4)
plt.plot(y5)
plt.plot(y6)


plt.show()

# %%
y2=np.array([5,10,125])
y1=np.array([20,30,456])
y3=np.array([20,302,9])
y4=np.array([120,31,1])
plot_list=[y1,y2,y3,y4]
for y in plot_list:
     plt.plot(y)
plt.show()

# %%
x1=np.array([1,3,5])
y1=np.array([1,4,5])
x2=np.array([1,2,5])
y2=np.array([2,4,9])
plt.plot(x1,y2)
plt.plot(x2,y2)
plt.plot(x1,y1)
plt.xlabel("KİLO")  #x ve y'ye ad verme
plt.ylabel("BOY")
plt.title("Veri") #başlık koymaya yarar
plt.grid() #arkaya kareli kağıt ekleme:)
plt.show()

# %%
x3=np.random.rand(3,12)
x1=np.random.rand(3,12)
x2=np.random.rand(3,12)
plt.plot(x1,x2)
plt.plot(x1,x3)
plt.show()

# %%
x3=np.random.rand(12,12)
x1=np.random.rand(12,12)
x2=np.random.rand(12,12)
plt.plot(x1,x2)
plt.plot(x1,x3)
plt.show()

# %%
x3=np.random.randint(0,23,245)
x1=np.random.randint(12,132,245)
x2=np.random.randint(112,192,245)
plt.plot(x1,x2)
plt.plot(x1,x3)
plt.plot(x2,x3)

plt.show()

# %%
for i in range(5):
 x1=np.random.randint(12,132,245)
 x2=np.random.randint(112,192,245)
 plt.plot(x1,x2)

# %%
x1=np.random.randint(1,5,8)
y2=np.random.randint(12,20,8)
plt.subplot(2,1,1)#satır sütun ve kaçıncı grafik olduğu parametreler
plt.plot(x1,y2)


y1=np.random.randint(1,5,11)
x2=np.random.randint(2,4,11)
plt.subplot(2,1,2)
plt.plot(y1,x2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x1=np.random.randint(100,9999,111)
y2=np.random.randint(162,2660,111)
y1=np.random.randint(225,4435,111)
x2=np.random.randint(133,1499,111)
plt.scatter(x1,y2,color='purple',alpha=0.5)#alpha=saydamlık oranını değiştirir
plt.scatter(x2,y2,color="brown",alpha=0.5)
plt.scatter(y1,y2,color="green")
plt.scatter(x1,x2,color="yellow")
plt.colorbar() #renkbarı gözükür
plt.title("Yıllara Göre Şehirlerin Nüfus Oranı",color="red")
plt.show()

# %%
x1=np.random.randint(100,999,25)
y2=np.random.randint(162,660,25)
size=np.random.randint(1,1260,25)
plt.scatter(x1,y2,s=size)
plt.show()

# %%
x1=np.random.randint(100,9999,25)
y2=np.random.randint(162,2660,25)
size=np.random.randint(1,1260,25)
plt.scatter(x1,y2,s=size,c=np.random.randint(1,100,25),cmap="nipy_spectral")
plt.colorbar()
plt.show()

# %%
x=np.array(["Elma","Armut","Çilek","Kayısı"])
y=np.array([5,12,3,13])
plt.bar(x,y,width=0.3) #width genişlik belirtiyor
plt.title("Sınıfta Kim Hangi Meyveyi Seviyor?")
plt.show()

# %%
x=np.random.normal(12201,90,5330)
plt.hist(x)
plt.title("Yıllara Göre Sumatra Orangutanı Sayısı ")
plt.show()

# %% [markdown]
# ##

# %%
y=np.array([45,15,34,6])
labels=(["Barış Partisi","Kaos Partisi","Sevgi Partisi","Savaş Partisi"])
plt.pie(y,labels=labels,explode=ayirici,shadow=True)
ayirici=[0.1,0,0,0.1]
plt.title("Oy Oranları",color="brown")
plt.legend() #yanda remkleri ifade eder
plt.show()

# %%
import pandas as pd
euro=pd.read_csv('../input/euro12/Euro 2012 stats TEAM.csv')

# %%
y=euro["Goals"]
labels=euro["Team"]
plt.pie(y,labels=labels)
plt.show()

# %%
y=euro["Offsides"]
labels=euro["Team"].apply(lambda item:item[0:3])#takımların ilk 3harfini alıyoruz bu fonksiyon ile
plt.bar(labels,y)
plt.show()

# %%
x=euro["Shots on target"]
y=euro["Goals"]
colors=np.random.randint(0,150,euro["Goals"].count())
size=np.random.randint(0,150,euro["Goals"].count())
plt.scatter(x,y,c=colors,s=size,alpha=0.5,cmap="nipy_spectral")
plt.colorbar()
plt.show()

# %%
x=euro["Penalty goals"]
y=euro["Team"].apply(lambda item:item[0:3])
plt.bar(y,x)
plt.show()

# %%
x=euro["Passes"]
y=euro["Team"].apply(lambda item:item[0:3])
plt.plot(y,x)
plt.show()

# %%
x=euro["Fouls Won"]
y=euro["Team"].apply(lambda item:item[0:3])
plt.plot(y,x)
plt.show()
